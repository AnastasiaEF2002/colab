# %%
import pandas as pd

df = pd.read_csv("hf://datasets/wykonos/movies/movies_dataset.csv")
df
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
#             id                                title  \
# 0       385687                               Fast X
# 1       758323                  The Pope's Exorcist
# 2       640146    Ant-Man and the Wasp: Quantumania
# 3       677179                            Creed III
# 4       502356          The Super Mario Bros. Movie
# ...        ...                                  ...
# 722791  900760  A Incessante Conquista da Escuridão
# 722792  957818                  Hollywood Varieties
# 722793  648905                 A Man Must Be Strong
# 722794  576855                        Stastriptease
# 722795  968161                        Gising Sining
#
#                                            genres original_language  \
# 0                           Action-Crime-Thriller                en
# 1                         Horror-Mystery-Thriller                en
# 2                Action-Adventure-Science Fiction                en
# 3                                    Drama-Action                en
# 4       Animation-Family-Adventure-Fantasy-Comedy                en
# ...                                           ...               ...
# 722791                                        NaN                pt
# 722792                                     Comedy                en
# 722793                                        NaN                it
# 722794                                        NaN                de
# 722795                                        NaN                tl
#
#                                                  overview  popularity  \
# 0       Over many missions and against impossible odds...    6682.100
# 1       Father Gabriele Amorth Chief Exorcist of the V...    5953.227
# 2       Super-Hero partners Scott Lang and Hope van Dy...    4425.387
# 3       After dominating the boxing world Adonis Creed...    3994.342
# 4       While working underground to fix a water main ...    3859.926
# ...                                                   ...         ...
# 722791  Two voices talk about the impermanence of the ...       0.600
# 722792  Entertainment trade-paper headlines report the...       0.600
# 722793  Jack starts the transition in order to let his...       0.600
# 722794                                                NaN       0.600
# 722795  In a country where fascism foolishness of peop...       0.600
#
#                                      production_companies release_date  \
# 0       Universal Pictures-Original Film-One Race-Perf...   2023-05-17
# 1       Screen Gems-2.0 Entertainment-Jesus & Mary-Wor...   2023-04-05
# 2                  Marvel Studios-Kevin Feige Productions   2023-02-15
# 3       Metro-Goldwyn-Mayer-Proximity Media-Balboa Pro...   2023-03-01
# 4                Universal Pictures-Illumination-Nintendo   2023-04-05
# ...                                                   ...          ...
# 722791                                                NaN   2021-04-15
# 722792                                                NaN   1950-01-01
# 722793                                                NaN   2019-11-19
# 722794                                                NaN   2018-06-07
# 722795                                          Studio RD          NaN
#
#              budget       revenue  runtime    status  \
# 0       340000000.0  6.867000e+08    142.0  Released
# 1        18000000.0  6.567582e+07    103.0  Released
# 2       200000000.0  4.757662e+08    125.0  Released
# 3        75000000.0  2.690000e+08    116.0  Released
# 4       100000000.0  1.278767e+09     92.0  Released
# ...             ...           ...      ...       ...
# 722791          0.0  0.000000e+00     10.0  Released
# 722792          0.0  0.000000e+00     60.0  Released
# 722793          0.0  0.000000e+00     61.0  Released
# 722794          0.0  0.000000e+00      NaN  Released
# 722795          0.0  0.000000e+00     19.0  Released
#
#                                                   tagline  vote_average  \
# 0                             The end of the road begins.         7.331
# 1       Inspired by the actual files of Father Gabriel...         7.433
# 2                 Witness the beginning of a new dynasty.         6.507
# 3                           You can't run from your past.         7.262
# 4                                                     NaN         7.764
# ...                                                   ...           ...
# 722791                                                NaN         0.000
# 722792                  Big time Vaudeville on the screen         0.000
# 722793                                                NaN         0.000
# 722794                                                NaN         0.000
# 722795                                                NaN         0.000
#
#         vote_count                                            credits  \
# 0           1856.0  Vin Diesel-Michelle Rodriguez-Tyrese Gibson-Lu...
# 1            545.0  Russell Crowe-Daniel Zovatto-Alex Essoe-Franco...
# 2           2811.0  Paul Rudd-Evangeline Lilly-Jonathan Majors-Kat...
# 3           1129.0  Michael B. Jordan-Tessa Thompson-Jonathan Majo...
# 4           4042.0  Chris Pratt-Charlie Day-Anya Taylor-Joy-Jack B...
# ...            ...                                                ...
# 722791         0.0                                         Rita Poças
# 722792         0.0  Robert Alda-Ken Trietsch-Paul Trietsch-Al Shaw...
# 722793         0.0                                                NaN
# 722794         0.0                                                NaN
# 722795         0.0                               Ruka Azuma-Mel Perez
#
#                                                  keywords  \
# 0                       sequel-revenge-racing-family-cars
# 1       spain-rome italy-vatican-pope-pig-possession-c...
# 2       hero-ant-sequel-superhero-based on comic-famil...
# 3       philadelphia pennsylvania-husband wife relatio...
# 4       video game-gorilla-plumber-magic mushroom-anth...
# ...                                                   ...
# 722791                                                NaN
# 722792                                                NaN
# 722793                                                NaN
# 722794                                                NaN
# 722795                                                NaN
#
#                              poster_path                     backdrop_path  \
# 0       /fiVW06jE7z9YnO4trhaMEdclSiC.jpg  /4XM8DUTQb3lhLemJC51Jx4a2EuA.jpg
# 1       /9JBEPLTPSm0d1mbEcLxULjJq9Eh.jpg  /hiHGRbyTcbZoLsYYkO4QiCLYe34.jpg
# 2       /qnqGbB22YJ7dSs4o6M7exTpNxPz.jpg  /m8JTwHFwX7I7JY5fPe4SjqejWag.jpg
# 3       /cvsXj3I9Q2iyyIo95AecSd1tad7.jpg  /5i6SjyDbDWqyun8klUuCxrlFbyw.jpg
# 4       /qNBAXBIQlnOThrVvA6mA2B5ggV6.jpg  /2klQ1z1fcHGgQPevbEQdkCnzyuS.jpg
# ...                                  ...                               ...
# 722791  /l2cEYTvqgsi0tvxRHZYdEQKPBLM.jpg                               NaN
# 722792                               NaN                               NaN
# 722793  /fKvCVxVjShCTTOpBZeOYGsEwisK.jpg                               NaN
# 722794                               NaN                               NaN
# 722795   /jv34KgS7D997H5kbVYxKLJRScg.jpg                               NaN
#
#                                           recommendations
# 0       19603-445954-697843-603692-781009-502356-74735...
# 1       713704-296271-502356-1076605-1084225-1008005-9...
# 2       823999-676841-868759-734048-267805-965839-1033...
# 3       965839-267805-943822-842942-1035806-823999-107...
# 4       713704-385687-640146-60898-758323-1008005-4935...
# ...                                                   ...
# 722791                                                NaN
# 722792                                                NaN
# 722793                                                NaN
# 722794                                                NaN
# 722795                                                NaN
#
# [722796 rows x 20 columns]

# %%
keep_col=['popularity','budget','revenue','runtime','vote_average','vote_count']
df=df[keep_col]
df
# Out:
#         popularity       budget       revenue  runtime  vote_average  \
# 0         6682.100  340000000.0  6.867000e+08    142.0         7.331
# 1         5953.227   18000000.0  6.567582e+07    103.0         7.433
# 2         4425.387  200000000.0  4.757662e+08    125.0         6.507
# 3         3994.342   75000000.0  2.690000e+08    116.0         7.262
# 4         3859.926  100000000.0  1.278767e+09     92.0         7.764
# ...            ...          ...           ...      ...           ...
# 722791       0.600          0.0  0.000000e+00     10.0         0.000
# 722792       0.600          0.0  0.000000e+00     60.0         0.000
# 722793       0.600          0.0  0.000000e+00     61.0         0.000
# 722794       0.600          0.0  0.000000e+00      NaN         0.000
# 722795       0.600          0.0  0.000000e+00     19.0         0.000
#
#         vote_count
# 0           1856.0
# 1            545.0
# 2           2811.0
# 3           1129.0
# 4           4042.0
# ...            ...
# 722791         0.0
# 722792         0.0
# 722793         0.0
# 722794         0.0
# 722795         0.0
#
# [722796 rows x 6 columns]

# %%
df=df.dropna()
df
# Out:
#         popularity       budget       revenue  runtime  vote_average  \
# 0         6682.100  340000000.0  6.867000e+08    142.0         7.331
# 1         5953.227   18000000.0  6.567582e+07    103.0         7.433
# 2         4425.387  200000000.0  4.757662e+08    125.0         6.507
# 3         3994.342   75000000.0  2.690000e+08    116.0         7.262
# 4         3859.926  100000000.0  1.278767e+09     92.0         7.764
# ...            ...          ...           ...      ...           ...
# 722789       0.600          0.0  0.000000e+00     18.0         0.000
# 722791       0.600          0.0  0.000000e+00     10.0         0.000
# 722792       0.600          0.0  0.000000e+00     60.0         0.000
# 722793       0.600          0.0  0.000000e+00     61.0         0.000
# 722795       0.600          0.0  0.000000e+00     19.0         0.000
#
#         vote_count
# 0           1856.0
# 1            545.0
# 2           2811.0
# 3           1129.0
# 4           4042.0
# ...            ...
# 722789         0.0
# 722791         0.0
# 722792         0.0
# 722793         0.0
# 722795         0.0
#
# [688346 rows x 6 columns]

# %%
df.corr()
# Out:
#               popularity    budget   revenue   runtime  vote_average  \
# popularity      1.000000  0.157097  0.213215 -0.000080      0.067027
# budget          0.157097  1.000000  0.494179 -0.000050      0.054764
# revenue         0.213215  0.494179  1.000000 -0.000048      0.065658
# runtime        -0.000080 -0.000050 -0.000048  1.000000     -0.001178
# vote_average    0.067027  0.054764  0.065658 -0.001178      1.000000
# vote_count      0.169710  0.435530  0.769463 -0.000076      0.100398
#
#               vote_count
# popularity      0.169710
# budget          0.435530
# revenue         0.769463
# runtime        -0.000076
# vote_average    0.100398
# vote_count      1.000000

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing
X = df.drop(['popularity'],axis= 1)
y = df['popularity']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=42)
model = LinearRegression()
model.fit(X_train,y_train)
predictions = model.predict(X_test)
print(
  'mean_squared_error : ', mean_squared_error(y_test, predictions))
print(
  'mean_absolute_error : ', mean_absolute_error(y_test, predictions))
# Out:
# mean_squared_error :  365.5833255853709
# mean_absolute_error :  1.3914584115356992

# %%
model.intercept_
# Out:
# 0.8522959184796808

# %%
import numpy as np

coefficients = model.coef_

rounded_coefficients = [round(coef, 3) for coef in coefficients]

print(rounded_coefficients)
# Out:
# [0.0, -0.0, -0.0, 0.301, 0.003]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing
X = df.drop(['popularity','vote_count'],axis= 1)
y = df['popularity']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=42)
model = LinearRegression()
model.fit(X_train,y_train)
predictions = model.predict(X_test)
print(
  'mean_squared_error : ', mean_squared_error(y_test, predictions))
print(
  'mean_absolute_error : ', mean_absolute_error(y_test, predictions))
# Out:
# mean_squared_error :  365.3426128074847
# mean_absolute_error :  1.4361290547901253

# %%
model.intercept_
# Out:
# 0.8463442589731969

# %%
import numpy as np

coefficients = model.coef_

rounded_coefficients = [round(coef, 3) for coef in coefficients]

print(rounded_coefficients)
# Out:
# [0.0, 0.0, -0.0, 0.316]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing
X = df.drop(['popularity','vote_count','budget'],axis= 1)
y = df['popularity']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=42)
model = LinearRegression()
model.fit(X_train,y_train)
predictions = model.predict(X_test)
print(
  'mean_squared_error : ', mean_squared_error(y_test, predictions))
print(
  'mean_absolute_error : ', mean_absolute_error(y_test, predictions))
# Out:
# mean_squared_error :  357.8599971275909
# mean_absolute_error :  1.4829035923566432

# %%
model.intercept_
# Out:
# 0.8758652677930276

# %%
import numpy as np

coefficients = model.coef_

rounded_coefficients = [round(coef, 3) for coef in coefficients]

print(rounded_coefficients)
# Out:
# [0.0, -0.0, 0.346]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing
X = df.drop(['popularity','vote_count','budget','runtime'],axis= 1)
y = df['popularity']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=42)
model = LinearRegression()
model.fit(X_train,y_train)
predictions = model.predict(X_test)
print(
  'mean_squared_error : ', mean_squared_error(y_test, predictions))
print(
  'mean_absolute_error : ', mean_absolute_error(y_test, predictions))
# Out:
# mean_squared_error :  357.85999680430155
# mean_absolute_error :  1.4829016571109939

# %%
model.intercept_
# Out:
# 0.8758594664147985

# %%
import numpy as np

coefficients = model.coef_

rounded_coefficients = [round(coef, 15) for coef in coefficients]

print(rounded_coefficients)
# Out:
# [1.46046332e-07, 0.346454864999245]

# %%
X = df.drop(['revenue'],axis= 1)
y = df['revenue']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=42)
model = LinearRegression()
model.fit(X_train,y_train)
predictions = model.predict(X_test)
print(
  'mean_squared_error : ', mean_squared_error(y_test, predictions))
print(
  'mean_absolute_error : ', mean_absolute_error(y_test, predictions))
# Out:
# mean_squared_error :  172911531704403.2
# mean_absolute_error :  969444.4139028442

# %%
model.intercept_
# Out:
# -3098.1002035896527

# %%
import numpy as np

coefficients = model.coef_

rounded_coefficients = [round(coef, 15) for coef in coefficients]

print(rounded_coefficients)
# Out:
# [-40.94160049634473, 0.838649499822774, -0.000106748449194, -95230.91430498452, 30988.67065947162]

# %%
X = df.drop(['vote_average'],axis= 1)
y = df['vote_average']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=42)
model = LinearRegression()
model.fit(X_train,y_train)
predictions = model.predict(X_test)
print(
  'mean_squared_error : ', mean_squared_error(y_test, predictions))
print(
  'mean_absolute_error : ', mean_absolute_error(y_test, predictions))
# Out:
# mean_squared_error :  10.036442791560875
# mean_absolute_error :  2.9207699648695153

# %%
model.intercept_
# Out:
# 2.4780734838348457

# %%
import numpy as np

coefficients = model.coef_

rounded_coefficients = [round(coef, 15) for coef in coefficients]

print(rounded_coefficients)
# Out:
# [0.009158168753931, 1.4986017e-08, -8.119928e-09, -4.7986393e-08, 0.000918279600122]

# %%
X = df.drop(['vote_average','runtime'],axis= 1)
y = df['vote_average']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=42)
model = LinearRegression()
model.fit(X_train,y_train)
predictions = model.predict(X_test)
print(
  'mean_squared_error : ', mean_squared_error(y_test, predictions))
print(
  'mean_absolute_error : ', mean_absolute_error(y_test, predictions))
# Out:
# mean_squared_error :  10.036448665326319
# mean_absolute_error :  2.9207657795786615

# %%
model.intercept_
# Out:
# 2.4780353721349875

# %%
import numpy as np

coefficients = model.coef_

rounded_coefficients = [round(coef, 15) for coef in coefficients]

print(rounded_coefficients)
# Out:
# [0.009158270266046, 1.498622e-08, -8.119996e-09, 0.000918285698139]

# %%
# !pip install gplearn
# Out:
# Collecting gplearn
#   Downloading gplearn-0.4.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from gplearn) (1.3.2)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from gplearn) (1.4.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->gplearn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->gplearn) (1.13.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->gplearn) (3.5.0)
# Downloading gplearn-0.4.2-py3-none-any.whl (25 kB)
# Installing collected packages: gplearn
# Successfully installed gplearn-0.4.2

# %%
import numpy as np
import pandas as pd
from gplearn.genetic import SymbolicRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Загрузка данных
data = df

# Разделение данных на обучающую и тестовую выборки
X = data.drop('popularity', axis=1)
y = data['popularity']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=42)

# Создание объекта SymbolicRegressor
function_set = ['add', 'sub', 'mul', 'div', 'sqrt', 'log', 'sin', 'cos', 'neg', 'inv']
est_gp = SymbolicRegressor(population_size=50,
                           function_set=function_set,
                           generations=100,
                           stopping_criteria=0.01,
                           p_crossover=0.7,
                           p_subtree_mutation=0.2,
                           p_hoist_mutation=0.02,
                           p_point_mutation=0.01,
                           max_samples=0.9,
                           verbose=1,
                           parsimony_coefficient=0.01,
                           random_state=0,
                           feature_names=X_train.columns)

# Обучение модели
est_gp.fit(X_train, y_train)

# Оценка модели на тестовой выборке
y_pred = est_gp.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print('RMSE:', rmse)

# Вывод символьную формулы
print('Символьная формула:')
print(est_gp._program)

# Визуализация фактических и предсказанных значений
fig, ax = plt.subplots()
ax.scatter(y_test, y_test, label='Actual', color='blue')
ax.scatter(y_test, y_pred, label='Predicted', color='red')
plt.legend()
plt.xlabel('Actual Y')
plt.ylabel('Predicted Y')
plt.title('Actual vs. Predicted Y')
plt.show()
# Out:
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.52      3.68783e+06        2          1.29904          1.30639      1.34m
#    1     5.46           389247        4           1.2578          1.62675      1.40m
#    2     3.58          1.44113        3          1.23659          1.78783      1.05m
#    3     2.94          38527.3        3          1.23035          1.84403     29.87s
#    4     3.44          50750.4        3          1.21352          1.99547     29.67s
#    5     3.30            1.591        2          1.23592          1.87445     29.92s
#    6     3.38          18.7786        2           1.2053          2.14995     31.47s
#    7     2.56          1.34188        2          1.20908          2.11595     27.10s
#    8     2.36          21535.9        2          1.22297          1.99095     23.10s
#    9     2.28          26846.4        2           1.2474          1.77111     23.34s
#   10     2.30          59941.7        2          1.23782          1.85734     22.52s
#   11     2.26          26551.9        2          1.26611           1.6028     21.17s
#   12     2.76      2.75565e+07        2          1.22076          2.01083     21.62s
#   13     2.66      8.23498e+08        2          1.26753          1.58994     30.45s
#   14     2.34       1.0247e+08        2          1.22389           1.9827     33.41s
#   15     2.28          7725.83        2          1.20828          2.12322     33.42s
#   16     2.52          6464.03        2          1.24873          1.75916     33.92s
#   17     2.56         1.03e+08        3          1.24481          1.71388     36.97s
#   18     2.34           892430        2          1.19773          2.21813     33.23s
#   19     2.30          3.05384        3          1.19982          2.11875      1.59m
#   20     2.84          1.87152        3          1.20732          2.05127     29.44s
#   21     2.66          27037.2        2          1.23833          1.85279     21.57s
#   22     2.80          18963.3        2          1.25004          1.74736     20.56s
#   23     2.32          18719.3        3          1.23307          1.81956     20.01s
#   24     4.20          50483.5        2          1.20392          2.16239     25.72s
#   25     3.26           166289        1          1.27262          1.68065     24.05s
#   26     2.54          3.06475        1          1.25193          1.86688     18.39s
#   27     2.16      2.71642e+07        1          1.24419          1.93651     16.74s
#   28     1.78          45967.8        2          1.24681          1.77645     14.23s
#   29     1.92          27174.5        2          1.23334          1.89763     16.89s
#   30     2.18          7956.56        2          1.25399          1.71184     16.84s
#   31     2.62          19.2805        2          1.22553          1.96796     18.26s
#   32     2.58          46768.6        2          1.22742          1.95092     17.63s
#   33     2.72          16139.6        1          1.24686          1.91248     19.34s
#   34     2.02          26106.4        2          1.22484          1.97413     14.68s
#   35     2.40      1.10591e+07        2          1.21742          2.04091     16.10s
#   36     1.90      1.13996e+08        2          1.25983          1.65928     13.17s
#   37     2.42          36101.5        1          1.22299           2.1273     14.16s
#   38     2.12          48356.4        1          1.21449          2.20376     13.41s
#   39     2.28          7999.02        1          1.24008          1.97344     13.69s
#   40     1.58          34470.7        1          1.21349          2.21275     11.87s
#   41     1.58           856155        1           1.2519          1.86712     11.52s
#   42     2.26        7.053e+16        2          1.22829          1.93393     13.50s
#   43     2.30          9497.53        8          1.18891          1.21764     12.07s
#   44     2.04          27194.7        8           1.1934          1.17728     11.96s
#   45     5.08          15704.9        7          1.09134          1.29792     14.46s
#   46     7.32          3.05802        9          1.07013         0.788389     15.34s
#   47     6.32          5.81425        6         0.981444          1.27853     14.91s
#   48     6.60          6.18058        6         0.959672          1.47446     15.08s
#   49     6.68          6.31945        6          1.00916          1.02913     11.69s
#   50     5.56          9.38061        6         0.966092          1.41669     11.70s
#   51     5.90           7941.2        6         0.951577          1.54731     10.10s
#   52     5.80          3.64636        6         0.933839          1.70693     10.19s
#   53     6.06          34177.7        6         0.945034          1.60618     10.55s
#   54     5.86          7.86611        6         0.966193          1.41578     10.26s
#   55     5.72          102.031        6         0.930918          1.73322     10.10s
#   56     5.46          19799.6        6         0.880759         0.748173      8.34s
#   57     5.92          15620.5        6         0.838983          1.12412      9.61s
#   58     7.26          27367.1        6         0.823012          1.26785      8.97s
#   59     6.48           359327        6         0.815213          1.33803      8.54s
#   60     5.98          5.24186        6         0.830815          1.19762      8.46s
#   61     6.18          21.8688        6         0.824002          1.25894     10.82s
#   62     5.68           126083        6         0.817153          1.32057     12.52s
#   63     6.18          2.28038        6         0.770515          1.74027     12.15s
#   64     6.10          4801.75        6         0.857909         0.953806     10.49s
#   65     6.38          23.1376        6         0.826386          1.23749     11.39s
#   66     5.98      9.38432e+07        6         0.829474           1.2097     11.72s
#   67     6.38          30.2326        6         0.789022          1.57373     10.58s
#   68     6.30          277.498        6         0.821901          1.27785     11.53s
#   69     6.08          3.91834        6         0.795042          1.51955      9.41s
#   70     5.78          18018.9        6         0.817591          1.31663      9.15s
#   71     5.84          5.16192        6         0.857319         0.959109      9.66s
#   72     6.04      1.46679e+06        6          0.78797          1.58319      6.18s
#   73     5.88          20.7208        6         0.809218          1.39198      6.05s
#   74     5.24          4619.26        6         0.817909          1.31377      5.69s
#   75     5.24          19573.4        6         0.851516          1.01133      5.02s
#   76     5.38          99442.3        6         0.819829          1.29649      5.18s
#   77     5.54          25.7181        6         0.843048          1.08754      4.73s
#   78     5.54          3.43954        6         0.803828          1.44048      4.66s
#   79     6.44          19215.4        6         0.827104          1.23102      4.58s
#   80     6.20          2.75122        6          0.82365           1.2621      4.62s
#   81     6.08          4.77426        6         0.790457          1.56081      4.00s
#   82     6.00           5.8795        6           0.8196          1.29855      3.88s
#   83     5.48          4.40622        6         0.837235          1.13985      3.37s
#   84     5.60          4.40703        6         0.787342          1.58885      3.53s
#   85     5.82      2.66665e+07        6         0.788175          1.58135      3.29s
#   86     6.22          4.82038        6         0.803106          1.44699      2.89s
#   87     5.84          38009.8        6         0.811172          1.37439      2.68s
#   88     5.44          18804.5        6         0.814288          1.34635      2.43s
#   89     6.14            18732        6         0.831399          1.19237      2.37s
#   90     6.06          9452.11        6         0.855463         0.975818      2.27s
#   91     5.56          79.2864        6         0.824419          1.25519      1.68s
#   92     5.34          3.38902        6         0.838736          1.12634      1.50s
#   93     5.98          5.66187        6         0.801953          1.45735      1.27s
#   94     6.30          8093.26        6         0.801557          1.46092      1.24s
#   95     5.84           9.8216        6         0.773991          1.70899      0.88s
#   96     5.76          7902.87        6          0.79544          1.51597      0.71s
#   97     5.48          19554.5        6         0.817027           1.3217      0.42s
#   98     5.80          27015.2        6          0.80226          1.45459      0.25s
#   99     5.12      2.67873e+07        6         0.811678          1.36984      0.00s
# RMSE: 18.961299899802906
# Символьная формула:
# sqrt(add(0.352, mul(vote_count, 0.352)))

# %%
y_gp = est_gp.predict(X_test)
score_gp1 = est_gp.score(X_test, y_test)
score_gp1
# Out:
# 0.04287398666033493

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from gplearn.genetic import SymbolicRegressor
import sklearn
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sympy import *
from sklearn.utils.random import check_random_state
import graphviz
import time
dot_data = est_gp._program.export_graphviz()
graph = graphviz.Source(dot_data)
graph.render('images/ex1', format='png', cleanup=True)
graph

# %%
converter = {
    'add': lambda x, y: x + y,
    'sub': lambda x, y: x - y,
    'mul': lambda x, y: x * y,
    'div': lambda x, y: x / y,
    'neg': lambda x: -x,
    'pow': lambda x, y: x ** y,
    'sin': lambda x: sin(x),
    'cos': lambda x: cos(x),
    'inv': lambda x: 1 / x,
    'sqrt': lambda x: x ** 0.5,
    'pow3': lambda x: x ** 3
}
next_e = sympify(str(est_gp._program), locals=converter)
next_e
# Out:
# 0.593295878967653*(vote_count + 1)**0.5
